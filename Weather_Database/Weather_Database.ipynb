# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | bela
# Processing Record 3 of Set 1 | port blair
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | maksatikha
# Processing Record 7 of Set 1 | marakkanam
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | mangalia
# Processing Record 11 of Set 1 | hamilton
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | ormara
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | port-gentil
# Processing Record 21 of Set 1 | meulaboh
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | edd
# Processing Record 24 of Set 1 | hovd
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | horsham
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | half moon bay
# Processing Record 30 of Set 1 | bastia
# Processing Record 31 of Set 1 | raudeberg
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | aquin
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | kajaani
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | kaeo
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 1 | silver city
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | qasigiannguit
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | namibe
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | dongsheng
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | yarmouth
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | serafimovich
# Processing Record 6 of Set 2 | kollumerland
# City not found. Skipping...
# Processing Record 7 of Set 2 | manta
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | praia
# Processing Record 11 of Set 2 | linxia
# Processing Record 12 of Set 2 | kashi
# Processing Record 13 of Set 2 | ulaangom
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | jimenez
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | belaya gora
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 2 | palora
# Processing Record 26 of Set 2 | yabrud
# Processing Record 27 of Set 2 | pacific grove
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | lockport
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | port macquarie
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | hami
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | sala
# Processing Record 39 of Set 2 | labuhan
# Processing Record 40 of Set 2 | zhangye
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | port hedland
# Processing Record 43 of Set 2 | nouadhibou
# Processing Record 44 of Set 2 | buritizeiro
# Processing Record 45 of Set 2 | hofn
# Processing Record 46 of Set 2 | barcelos
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | sujangarh
# Processing Record 49 of Set 2 | rawson
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | muros
# Processing Record 2 of Set 3 | boyabat
# Processing Record 3 of Set 3 | san policarpo
# Processing Record 4 of Set 3 | sao raimundo nonato
# Processing Record 5 of Set 3 | linqiong
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | hambantota
# Processing Record 9 of Set 3 | ibirama
# Processing Record 10 of Set 3 | vallenar
# Processing Record 11 of Set 3 | anadyr
# Processing Record 12 of Set 3 | mogadishu
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | muzhi
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | urubicha
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | berbera
# Processing Record 21 of Set 3 | kapaa
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | batesville
# Processing Record 24 of Set 3 | srednekolymsk
# Processing Record 25 of Set 3 | alta floresta
# Processing Record 26 of Set 3 | touros
# Processing Record 27 of Set 3 | nizwa
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | waitati
# Processing Record 30 of Set 3 | dawei
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | comodoro rivadavia
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | chakwal
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 3 | marsh harbour
# Processing Record 38 of Set 3 | teguldet
# Processing Record 39 of Set 3 | lompoc
# Processing Record 40 of Set 3 | longyearbyen
# Processing Record 41 of Set 3 | shubarkuduk
# Processing Record 42 of Set 3 | seabra
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | egvekinot
# Processing Record 46 of Set 3 | bianzhuang
# Processing Record 47 of Set 3 | sanming
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | rodrigues alves
# Processing Record 50 of Set 3 | maceio
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | bathsheba
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | nemuro
# Processing Record 6 of Set 4 | klaksvik
# Processing Record 7 of Set 4 | muli
# Processing Record 8 of Set 4 | kargapolye
# City not found. Skipping...
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 4 | san quintin
# Processing Record 13 of Set 4 | kudahuvadhoo
# Processing Record 14 of Set 4 | scarborough
# Processing Record 15 of Set 4 | lubango
# Processing Record 16 of Set 4 | broken hill
# Processing Record 17 of Set 4 | cayenne
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | turinskaya sloboda
# Processing Record 20 of Set 4 | sibiti
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | evensk
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | santa isabel
# Processing Record 25 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 4 | carutapera
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | asfi
# Processing Record 29 of Set 4 | henties bay
# Processing Record 30 of Set 4 | qaqortoq
# Processing Record 31 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 4 | sept-iles
# Processing Record 33 of Set 4 | kochubey
# Processing Record 34 of Set 4 | stokmarknes
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | sinnamary
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | limulunga
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | kiama
# Processing Record 44 of Set 4 | taitung
# Processing Record 45 of Set 4 | xuanzhou
# Processing Record 46 of Set 4 | acari
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | anloga
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | te anau
# Processing Record 1 of Set 5 | le vauclin
# Processing Record 2 of Set 5 | kovylkino
# Processing Record 3 of Set 5 | siva
# Processing Record 4 of Set 5 | alpena
# Processing Record 5 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 5 | namie
# Processing Record 7 of Set 5 | tanout
# Processing Record 8 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | yuma
# Processing Record 10 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | aquiraz
# Processing Record 15 of Set 5 | ajdabiya
# Processing Record 16 of Set 5 | pangkalanbuun
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | sambava
# Processing Record 19 of Set 5 | poya
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | menongue
# Processing Record 22 of Set 5 | kenora
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | sahbuz
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | sechura
# Processing Record 27 of Set 5 | korla
# Processing Record 28 of Set 5 | christchurch
# Processing Record 29 of Set 5 | sao filipe
# Processing Record 30 of Set 5 | zhaotong
# Processing Record 31 of Set 5 | lagoa
# Processing Record 32 of Set 5 | jilin
# Processing Record 33 of Set 5 | poum
# Processing Record 34 of Set 5 | filadelfia
# Processing Record 35 of Set 5 | boa vista
# Processing Record 36 of Set 5 | goaigoaza
# City not found. Skipping...
# Processing Record 37 of Set 5 | salinopolis
# Processing Record 38 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 5 | esil
# Processing Record 40 of Set 5 | north myrtle beach
# Processing Record 41 of Set 5 | ancud
# Processing Record 42 of Set 5 | miles city
# Processing Record 43 of Set 5 | athabasca
# Processing Record 44 of Set 5 | goderich
# Processing Record 45 of Set 5 | codrington
# Processing Record 46 of Set 5 | imeni poliny osipenko
# Processing Record 47 of Set 5 | nanortalik
# Processing Record 48 of Set 5 | kolokani
# Processing Record 49 of Set 5 | bambous virieux
# Processing Record 50 of Set 5 | verkhnevilyuysk
# Processing Record 1 of Set 6 | ranong
# Processing Record 2 of Set 6 | naze
# Processing Record 3 of Set 6 | basco
# Processing Record 4 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 6 | praya
# Processing Record 6 of Set 6 | kieta
# Processing Record 7 of Set 6 | alice springs
# Processing Record 8 of Set 6 | karasjok
# Processing Record 9 of Set 6 | souillac
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | beringovskiy
# Processing Record 14 of Set 6 | nargana
# Processing Record 15 of Set 6 | doume
# Processing Record 16 of Set 6 | tabou
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | lengshuijiang
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | ribeira grande
# Processing Record 26 of Set 6 | kamina
# Processing Record 27 of Set 6 | hwange
# Processing Record 28 of Set 6 | hirekerur
# Processing Record 29 of Set 6 | castro
# Processing Record 30 of Set 6 | matamoros
# Processing Record 31 of Set 6 | mana
# Processing Record 32 of Set 6 | mabaruma
# Processing Record 33 of Set 6 | mora
# Processing Record 34 of Set 6 | yerbogachen
# Processing Record 35 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 36 of Set 6 | tautira
# Processing Record 37 of Set 6 | katobu
# Processing Record 38 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 6 | honiara
# Processing Record 40 of Set 6 | faanui
# Processing Record 41 of Set 6 | san jeronimo
# Processing Record 42 of Set 6 | libertador general san martin
# Processing Record 43 of Set 6 | hirara
# Processing Record 44 of Set 6 | torit
# Processing Record 45 of Set 6 | bahia blanca
# Processing Record 46 of Set 6 | pangai
# Processing Record 47 of Set 6 | erenhot
# Processing Record 48 of Set 6 | huicheng
# Processing Record 49 of Set 6 | aldan
# Processing Record 50 of Set 6 | shaunavon
# Processing Record 1 of Set 7 | mikhaylovka
# Processing Record 2 of Set 7 | paita
# Processing Record 3 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 7 | santa maria
# Processing Record 5 of Set 7 | tuatapere
# Processing Record 6 of Set 7 | bagn
# Processing Record 7 of Set 7 | lakeside
# Processing Record 8 of Set 7 | bealanana
# Processing Record 9 of Set 7 | playas
# Processing Record 10 of Set 7 | ergani
# Processing Record 11 of Set 7 | the valley
# Processing Record 12 of Set 7 | yerofey pavlovich
# Processing Record 13 of Set 7 | constitucion
# Processing Record 14 of Set 7 | sur
# Processing Record 15 of Set 7 | aitape
# Processing Record 16 of Set 7 | fare
# Processing Record 17 of Set 7 | puerto madero
# Processing Record 18 of Set 7 | adrar
# Processing Record 19 of Set 7 | ternate
# Processing Record 20 of Set 7 | los llanos de aridane
# Processing Record 21 of Set 7 | severnoye
# Processing Record 22 of Set 7 | biak
# Processing Record 23 of Set 7 | gamba
# Processing Record 24 of Set 7 | asosa
# Processing Record 25 of Set 7 | luganville
# Processing Record 26 of Set 7 | samarai
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | yarada
# Processing Record 29 of Set 7 | magadan
# Processing Record 30 of Set 7 | puerto madryn
# Processing Record 31 of Set 7 | lotofaga
# Processing Record 32 of Set 7 | goya
# Processing Record 33 of Set 7 | misratah
# Processing Record 34 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 35 of Set 7 | la sarre
# Processing Record 36 of Set 7 | baruun-urt
# Processing Record 37 of Set 7 | salalah
# Processing Record 38 of Set 7 | sarkikaraagac
# Processing Record 39 of Set 7 | buchanan
# Processing Record 40 of Set 7 | dunedin
# Processing Record 41 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 7 | chara
# Processing Record 43 of Set 7 | rio grande
# Processing Record 44 of Set 7 | kavieng
# Processing Record 45 of Set 7 | trairi
# Processing Record 46 of Set 7 | teya
# Processing Record 47 of Set 7 | grand-santi
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | oconomowoc
# Processing Record 50 of Set 7 | banda aceh
# Processing Record 1 of Set 8 | birao
# Processing Record 2 of Set 8 | neuquen
# Processing Record 3 of Set 8 | dordrecht
# Processing Record 4 of Set 8 | uptar
# Processing Record 5 of Set 8 | crisan
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | seoul
# Processing Record 8 of Set 8 | grand gaube
# Processing Record 9 of Set 8 | la ronge
# Processing Record 10 of Set 8 | lagoa formosa
# Processing Record 11 of Set 8 | paka
# Processing Record 12 of Set 8 | washim
# Processing Record 13 of Set 8 | loubomo
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | kutulik
# Processing Record 16 of Set 8 | daru
# Processing Record 17 of Set 8 | torbay
# Processing Record 18 of Set 8 | paranapanema
# Processing Record 19 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 8 | north bend
# Processing Record 21 of Set 8 | lanxi
# Processing Record 22 of Set 8 | faya
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | riyadh
# Processing Record 25 of Set 8 | tessalit
# Processing Record 26 of Set 8 | northam
# Processing Record 27 of Set 8 | doha
# Processing Record 28 of Set 8 | oksfjord
# Processing Record 29 of Set 8 | kosh-agach
# Processing Record 30 of Set 8 | nome
# Processing Record 31 of Set 8 | ouesso
# Processing Record 32 of Set 8 | shetpe
# Processing Record 33 of Set 8 | kalaiya
# Processing Record 34 of Set 8 | betare oya
# Processing Record 35 of Set 8 | yulara
# Processing Record 36 of Set 8 | mahanoro
# Processing Record 37 of Set 8 | voljevac
# Processing Record 38 of Set 8 | ahipara
# Processing Record 39 of Set 8 | marolambo
# Processing Record 40 of Set 8 | vila franca do campo
# Processing Record 41 of Set 8 | mitsamiouli
# Processing Record 42 of Set 8 | kununurra
# Processing Record 43 of Set 8 | mezhdurechensk
# Processing Record 44 of Set 8 | jaisalmer
# Processing Record 45 of Set 8 | khash
# Processing Record 46 of Set 8 | puerto narino
# Processing Record 47 of Set 8 | margate
# Processing Record 48 of Set 8 | moose factory
# Processing Record 49 of Set 8 | alvaraes
# Processing Record 50 of Set 8 | umm lajj
# Processing Record 1 of Set 9 | eureka
# Processing Record 2 of Set 9 | santa catarina mita
# Processing Record 3 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 9 | sula
# Processing Record 5 of Set 9 | nivala
# Processing Record 6 of Set 9 | imperial beach
# Processing Record 7 of Set 9 | payyannur
# Processing Record 8 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 9 of Set 9 | castro-urdiales
# Processing Record 10 of Set 9 | oktyabrskiy
# Processing Record 11 of Set 9 | providencia
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | araouane
# Processing Record 14 of Set 9 | hay river
# Processing Record 15 of Set 9 | axim
# Processing Record 16 of Set 9 | kaduqli
# Processing Record 17 of Set 9 | hokitika
# Processing Record 18 of Set 9 | los algarrobos
# Processing Record 19 of Set 9 | sisimiut
# Processing Record 20 of Set 9 | flinders
# Processing Record 21 of Set 9 | udachnyy
# Processing Record 22 of Set 9 | lasa
# Processing Record 23 of Set 9 | montepuez
# Processing Record 24 of Set 9 | lakatoro
# Processing Record 25 of Set 9 | ballina
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | huatusco
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | kota belud
# Processing Record 30 of Set 9 | varhaug
# Processing Record 31 of Set 9 | sabha
# Processing Record 32 of Set 9 | venado tuerto
# Processing Record 33 of Set 9 | kuloy
# Processing Record 34 of Set 9 | den helder
# Processing Record 35 of Set 9 | ambilobe
# Processing Record 36 of Set 9 | basak
# Processing Record 37 of Set 9 | taksimo
# Processing Record 38 of Set 9 | bowen
# Processing Record 39 of Set 9 | estelle
# Processing Record 40 of Set 9 | kirensk
# Processing Record 41 of Set 9 | midleton
# Processing Record 42 of Set 9 | buala
# Processing Record 43 of Set 9 | ucluelet
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | karachi
# Processing Record 46 of Set 9 | kaliua
# Processing Record 47 of Set 9 | pryvillya
# Processing Record 48 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 9 | teguise
# Processing Record 50 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 10 | plover
# Processing Record 2 of Set 10 | mahajanga
# Processing Record 3 of Set 10 | oeiras
# Processing Record 4 of Set 10 | harsin
# Processing Record 5 of Set 10 | nyurba
# Processing Record 6 of Set 10 | nanakuli
# Processing Record 7 of Set 10 | paamiut
# Processing Record 8 of Set 10 | yamada
# Processing Record 9 of Set 10 | aloleng
# Processing Record 10 of Set 10 | sakakah
# Processing Record 11 of Set 10 | la uribe
# City not found. Skipping...
# Processing Record 12 of Set 10 | karratha
# Processing Record 13 of Set 10 | mto wa mbu
# Processing Record 14 of Set 10 | sunyani
# Processing Record 15 of Set 10 | arlit
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | rafai
# Processing Record 18 of Set 10 | malinyi
# Processing Record 19 of Set 10 | luang prabang
# Processing Record 20 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 10 | richards bay
# Processing Record 22 of Set 10 | holguin
# Processing Record 23 of Set 10 | belyy yar
# Processing Record 24 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 25 of Set 10 | nalut
# Processing Record 26 of Set 10 | coihaique
# Processing Record 27 of Set 10 | abha
# Processing Record 28 of Set 10 | avera
# Processing Record 29 of Set 10 | acatlan
# Processing Record 30 of Set 10 | kanata
# Processing Record 31 of Set 10 | khilok
# Processing Record 32 of Set 10 | tiarei
# Processing Record 33 of Set 10 | sampit
# Processing Record 34 of Set 10 | discovery bay
# Processing Record 35 of Set 10 | hanna
# Processing Record 36 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 10 | chillicothe
# Processing Record 38 of Set 10 | rebrikha
# Processing Record 39 of Set 10 | saint-louis
# Processing Record 40 of Set 10 | eyl
# Processing Record 41 of Set 10 | aleppo
# Processing Record 42 of Set 10 | guanare
# Processing Record 43 of Set 10 | lac du bonnet
# Processing Record 44 of Set 10 | santa cruz de tenerife
# Processing Record 45 of Set 10 | poddorye
# Processing Record 46 of Set 10 | tutoia
# Processing Record 47 of Set 10 | arcachon
# Processing Record 48 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | verkhnyaya khava
# Processing Record 50 of Set 10 | navapur
# City not found. Skipping...
# Processing Record 1 of Set 11 | kifri
# Processing Record 2 of Set 11 | vanimo
# Processing Record 3 of Set 11 | charters towers
# Processing Record 4 of Set 11 | felanitx
# Processing Record 5 of Set 11 | upernavik
# Processing Record 6 of Set 11 | paliseul
# Processing Record 7 of Set 11 | atar
# Processing Record 8 of Set 11 | maningrida
# Processing Record 9 of Set 11 | kantunilkin
# Processing Record 10 of Set 11 | broome
# Processing Record 11 of Set 11 | pemba
# Processing Record 12 of Set 11 | kasempa
# Processing Record 13 of Set 11 | wangaratta
# Processing Record 14 of Set 11 | roseland
# Processing Record 15 of Set 11 | ketchikan
# Processing Record 16 of Set 11 | mitu
# Processing Record 17 of Set 11 | mecca
# Processing Record 18 of Set 11 | sete
# Processing Record 19 of Set 11 | akdepe
# Processing Record 20 of Set 11 | lavrentiya
# Processing Record 21 of Set 11 | ust-tsilma
# Processing Record 22 of Set 11 | yanaul
# Processing Record 23 of Set 11 | caohe
# Processing Record 24 of Set 11 | ouallam
# Processing Record 25 of Set 11 | carauari
# Processing Record 26 of Set 11 | camacupa
# Processing Record 27 of Set 11 | kaitangata
# Processing Record 28 of Set 11 | qingan
# City not found. Skipping...
# Processing Record 29 of Set 11 | agadez
# Processing Record 30 of Set 11 | labrea
# Processing Record 31 of Set 11 | sokolo
# Processing Record 32 of Set 11 | tortoli
# Processing Record 33 of Set 11 | jiuquan
# Processing Record 34 of Set 11 | severo-yeniseyskiy
# Processing Record 35 of Set 11 | remedios
# Processing Record 36 of Set 11 | tezu
# Processing Record 37 of Set 11 | torres
# Processing Record 38 of Set 11 | mezen
# Processing Record 39 of Set 11 | walvis bay
# Processing Record 40 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | siocon
# Processing Record 42 of Set 11 | gurupa
# Processing Record 43 of Set 11 | jawhar
# Processing Record 44 of Set 11 | cacak
# Processing Record 45 of Set 11 | nuuk
# Processing Record 46 of Set 11 | shimanovsk
# Processing Record 47 of Set 11 | urucuca
# Processing Record 48 of Set 11 | kocevje
# Processing Record 49 of Set 11 | betioky
# Processing Record 50 of Set 11 | sao jose da coroa grande
# Processing Record 1 of Set 12 | tel aviv-yafo
# Processing Record 2 of Set 12 | ugoofaaru
# Processing Record 3 of Set 12 | xadani
# City not found. Skipping...
# Processing Record 4 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 12 | lawrenceburg
# Processing Record 6 of Set 12 | oyama
# Processing Record 7 of Set 12 | tarakan
# Processing Record 8 of Set 12 | taoudenni
# Processing Record 9 of Set 12 | seda
# Processing Record 10 of Set 12 | angoram
# Processing Record 11 of Set 12 | narsaq
# Processing Record 12 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 14 of Set 12 | kirakira
# Processing Record 15 of Set 12 | turka
# Processing Record 16 of Set 12 | semey
# Processing Record 17 of Set 12 | iberia
# Processing Record 18 of Set 12 | destin
# Processing Record 19 of Set 12 | bubaque
# Processing Record 20 of Set 12 | chernyshevsk
# Processing Record 21 of Set 12 | denau
# City not found. Skipping...
# Processing Record 22 of Set 12 | guarapari
# Processing Record 23 of Set 12 | mazyr
# Processing Record 24 of Set 12 | alenquer
# Processing Record 25 of Set 12 | awbari
# Processing Record 26 of Set 12 | itaperuna
# Processing Record 27 of Set 12 | tiznit
# Processing Record 28 of Set 12 | vao
# Processing Record 29 of Set 12 | amudat
# Processing Record 30 of Set 12 | zambezi
# Processing Record 31 of Set 12 | kungsbacka
# Processing Record 32 of Set 12 | kloulklubed
# Processing Record 33 of Set 12 | kerouane
# Processing Record 34 of Set 12 | vaitape
# Processing Record 35 of Set 12 | kijang
# Processing Record 36 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 12 | marrakesh
# Processing Record 38 of Set 12 | kudat
# Processing Record 39 of Set 12 | sodertalje
# City not found. Skipping...
# Processing Record 40 of Set 12 | puerto del rosario
# Processing Record 41 of Set 12 | kitimat
# Processing Record 42 of Set 12 | madimba
# Processing Record 43 of Set 12 | necochea
# Processing Record 44 of Set 12 | san jose
# Processing Record 45 of Set 12 | apache junction
# Processing Record 46 of Set 12 | lucapa
# Processing Record 47 of Set 12 | noormarkku
# Processing Record 48 of Set 12 | puerto colombia
# Processing Record 49 of Set 12 | rewari
# Processing Record 50 of Set 12 | mocajuba
# Processing Record 1 of Set 13 | kargasok
# Processing Record 2 of Set 13 | buraydah
# Processing Record 3 of Set 13 | saint-georges
# Processing Record 4 of Set 13 | acajutla
# Processing Record 5 of Set 13 | alappuzha
# Processing Record 6 of Set 13 | eyrarbakki
# Processing Record 7 of Set 13 | digby
# Processing Record 8 of Set 13 | tshikapa
# Processing Record 9 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 13 | tomohon
# Processing Record 11 of Set 13 | point pleasant
# Processing Record 12 of Set 13 | russell
# Processing Record 13 of Set 13 | viransehir
# Processing Record 14 of Set 13 | ixtapa
# Processing Record 15 of Set 13 | mehamn
# Processing Record 16 of Set 13 | beira
# Processing Record 17 of Set 13 | yeppoon
# Processing Record 18 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 13 | tahe
# Processing Record 20 of Set 13 | ningan
# City not found. Skipping...
# Processing Record 21 of Set 13 | bontang
# Processing Record 22 of Set 13 | saint marys
# Processing Record 23 of Set 13 | salobrena
# Processing Record 24 of Set 13 | sarakhs
# Processing Record 25 of Set 13 | belmonte
# Processing Record 26 of Set 13 | conde
# Processing Record 27 of Set 13 | husavik
# Processing Record 28 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 13 | buckingham
# Processing Record 30 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 13 | khuzhir
# Processing Record 32 of Set 13 | kruisfontein
# Processing Record 33 of Set 13 | san ramon
# Processing Record 34 of Set 13 | jiehu
# Processing Record 35 of Set 13 | almaty
# Processing Record 36 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 13 | gazli
# Processing Record 38 of Set 13 | amol
# Processing Record 39 of Set 13 | maimon
# City not found. Skipping...
# Processing Record 40 of Set 13 | okhotsk
# Processing Record 41 of Set 13 | lososina
# Processing Record 42 of Set 13 | dillon
# Processing Record 43 of Set 13 | isangel
# Processing Record 44 of Set 13 | iskateley
# Processing Record 45 of Set 13 | aykhal
# Processing Record 46 of Set 13 | noumea
# Processing Record 47 of Set 13 | deputatskiy
# Processing Record 48 of Set 13 | benguela
# Processing Record 49 of Set 13 | havelock
# Processing Record 50 of Set 13 | cutlerville
# Processing Record 1 of Set 14 | alcantara
# Processing Record 2 of Set 14 | wynyard
# Processing Record 3 of Set 14 | harper
# Processing Record 4 of Set 14 | gafargaon
# Processing Record 5 of Set 14 | monrovia
# Processing Record 6 of Set 14 | bilma
# Processing Record 7 of Set 14 | black diamond
# Processing Record 8 of Set 14 | hurricane
# Processing Record 9 of Set 14 | verkh-usugli
# Processing Record 10 of Set 14 | catamarca
# Processing Record 11 of Set 14 | abu samrah
# Processing Record 12 of Set 14 | tagab
# Processing Record 13 of Set 14 | mayo
# Processing Record 14 of Set 14 | jasper
# Processing Record 15 of Set 14 | saint-pierre
# Processing Record 16 of Set 14 | lander
# Processing Record 17 of Set 14 | krasnystaw
# Processing Record 18 of Set 14 | kiunga
# Processing Record 19 of Set 14 | puerto palomas
# Processing Record 20 of Set 14 | ust-kalmanka
# Processing Record 21 of Set 14 | pacifica
# Processing Record 22 of Set 14 | butka
# Processing Record 23 of Set 14 | mackenzie
# Processing Record 24 of Set 14 | brae
# Processing Record 25 of Set 14 | lyubech
# Processing Record 26 of Set 14 | kavaratti
# Processing Record 27 of Set 14 | pueblo
# Processing Record 28 of Set 14 | damara
# Processing Record 29 of Set 14 | aguililla
# Processing Record 30 of Set 14 | indramayu
# Processing Record 31 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 32 of Set 14 | dedza
# Processing Record 33 of Set 14 | zolnoye
# City not found. Skipping...
# Processing Record 34 of Set 14 | sicamous
# Processing Record 35 of Set 14 | gunjur
# Processing Record 36 of Set 14 | havre-saint-pierre
# Processing Record 37 of Set 14 | hualmay
# Processing Record 38 of Set 14 | jardim
# Processing Record 39 of Set 14 | dakar
# Processing Record 40 of Set 14 | pevek
# Processing Record 41 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 14 | mount isa
# Processing Record 43 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 14 | punta de bombon
# Processing Record 45 of Set 14 | nantucket
# Processing Record 46 of Set 14 | kampot
# Processing Record 47 of Set 14 | kamennogorsk
# Processing Record 48 of Set 14 | vestmanna
# Processing Record 49 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 50 of Set 14 | pio xii
# Processing Record 1 of Set 15 | coquimbo
# Processing Record 2 of Set 15 | arman
# Processing Record 3 of Set 15 | wanxian
# Processing Record 4 of Set 15 | pochutla
# Processing Record 5 of Set 15 | portland
# Processing Record 6 of Set 15 | watsa
# Processing Record 7 of Set 15 | dinard
# Processing Record 8 of Set 15 | clarksville
# Processing Record 9 of Set 15 | the pas
# Processing Record 10 of Set 15 | xuddur
# Processing Record 11 of Set 15 | pesaro
# Processing Record 12 of Set 15 | oistins
# Processing Record 13 of Set 15 | port hardy
# Processing Record 14 of Set 15 | dezful
# Processing Record 15 of Set 15 | lakshettipet
# Processing Record 16 of Set 15 | andra
# Processing Record 17 of Set 15 | salta
# Processing Record 18 of Set 15 | kebemer
# City not found. Skipping...
# Processing Record 19 of Set 15 | lake havasu city
# Processing Record 20 of Set 15 | jalu
# Processing Record 21 of Set 15 | constantine
# Processing Record 22 of Set 15 | cap malheureux
# Processing Record 23 of Set 15 | tallahassee
# Processing Record 24 of Set 15 | aksu
# Processing Record 25 of Set 15 | kibala
# Processing Record 26 of Set 15 | samarskoye
# Processing Record 27 of Set 15 | seymchan
# Processing Record 28 of Set 15 | adjumani
# Processing Record 29 of Set 15 | kinkala
# Processing Record 30 of Set 15 | krasnoselkup
# Processing Record 31 of Set 15 | trogir
# Processing Record 32 of Set 15 | murray bridge
# Processing Record 33 of Set 15 | bonthe
# Processing Record 34 of Set 15 | sayyan
# Processing Record 35 of Set 15 | san vicente
# Processing Record 36 of Set 15 | buenos aires
# Processing Record 37 of Set 15 | tokur
# Processing Record 38 of Set 15 | barahona
# Processing Record 39 of Set 15 | miyang
# Processing Record 40 of Set 15 | koster
# Processing Record 41 of Set 15 | hvittingfoss
# Processing Record 42 of Set 15 | karymskoye
# Processing Record 43 of Set 15 | kousseri
# Processing Record 44 of Set 15 | bereda
# Processing Record 45 of Set 15 | tianpeng
# Processing Record 46 of Set 15 | catuday
# Processing Record 47 of Set 15 | kostomuksha
# Processing Record 48 of Set 15 | denpasar
# Processing Record 49 of Set 15 | puerto ayacucho
# Processing Record 50 of Set 15 | kharar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Albany      US  42.6001  -73.9662     50.72        82         100
# 1        Bela      IN  25.9333   81.9833     78.96        82           6
# 2  Port Blair      IN  11.6667   92.7500     81.14        83         100
# 3       Vardo      NO  70.3705   31.1107     39.60        75          90
# 4      Atuona      PF  -9.8000 -139.0333     78.69        72          11
# 5  Maksatikha      RU  57.7970   35.8825     48.07        62          86
# 6  Marakkanam      IN  12.2000   79.9500     87.22        67          90
# 7      Barrow      US  71.2906 -156.7887     30.22        80          90
# 8     Ushuaia      AR -54.8000  -68.3000     29.86        93          90
# 9    Mangalia      RO  43.8000   28.5833     67.08        77          82
#
#    Wind Speed Current Description
# 0        3.74     overcast clouds
# 1        5.46           clear sky
# 2        6.42     overcast clouds
# 3       13.71     overcast clouds
# 4       10.65          few clouds
# 5        8.61     overcast clouds
# 6       14.52     overcast clouds
# 7        9.22     overcast clouds
# 8        9.22          light snow
# 9        9.37       broken clouds

# %%
#Export DataFrame to a CSV
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
